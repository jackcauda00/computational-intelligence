# %%
# Set covering problem: you need to select a certain number of blocks in order to cover all the initial sets
# Example: find the minimum number of items that together guarantee to cover something
# Definitions

# STATE = contains all the relevant informations to represent the current situation

# %% [markdown]
# Tile = set of points ==> it is PROBLEM_SIZE
#
# The problem is to maximize the number of not_taken or otherwise minimize the number of taken.
# In other words, covering all points at least once with the least number of tiles possible

# %%
from random import random
import numpy as np
from functools import reduce
from collections import namedtuple
from queue import PriorityQueue, SimpleQueue, LifoQueue

# %%
PROBLEM_SIZE = 5
NUM_SETS = 7

# %%
from typing import Sequence
sets = tuple(np.array([random() < .2 for _ in range(PROBLEM_SIZE)]) for _ in range(NUM_SETS))
State = namedtuple('State', ['taken', 'not_taken'])

# %%
def goal_check(state):
  #np.all = checks whether all elements are TRUE
  #reduce = applies the logical or to all elements of the specified iterable
  return np.all(reduce(np.logical_or, [sets[i] for i in state.taken], np.array([False for _ in range(PROBLEM_SIZE)])))

# %%
assert(goal_check(State(set(range(NUM_SETS)), set())), "Problem not solvable")
# Out:
# <>:1: SyntaxWarning: assertion is always true, perhaps remove parentheses?
# <>:1: SyntaxWarning: assertion is always true, perhaps remove parentheses?
# C:\Users\gcauda\AppData\Local\Temp\ipykernel_21368\987543073.py:1: SyntaxWarning: assertion is always true, perhaps remove parentheses?
#   assert(goal_check(State(set(range(NUM_SETS)), set())), "Problem not solvable")

# %%
from collections import namedtuple
State = namedtuple('State', ['taken', 'not_taken'])

# %%
#TEST: max taken - max not taken 

def new_heuristic(state):  #prendo il set che ha il max di true
    #print(np.max([np.sum(sets[i]) for i in state.taken])) #per tutti i set mi somma i true. Creo un array contenente le somme di tutti i set
    return np.max([np.sum(sets[i]) for i in state.not_taken]) #per tutti i set mi somma i true. Creo un array contenente le somme di tutti i set

# %%
#PROFESSOR'S TAKE ON THIS

def goal_check(state):
    # This is a binary output: did we reach a solution? True of False
    return np.all(reduce(
        np.logical_or,
        [sets[i] for i in state.taken],
        np.array([False for _ in range(PROBLEM_SIZE)]),
    ))


def distance(state): #H 
    # This is a numeric output that counts the amount of TRUEs in the given state. 
    # TRUE means "I am covering that individual point"
    # Since the PriorityQueue is ordered in reverse, we do PROBLEM_SIZE - [...]
    return PROBLEM_SIZE - sum(
        reduce(
            np.logical_or,
            [sets[i] for i in state.taken],
            np.array([False for _ in range(PROBLEM_SIZE)]),
        ))
    
def print_sets():
  print("PRINTING SETS:")
  for s in range(0,NUM_SETS):
    print(f"{s}) {sets[s]}")
  print("-"*25)  
      
def g(state):
    #print("\nELEMENTI DENTRO TAKEN\n")
    #print_sets()
    return len(state.taken)
    
  

print_sets()

frontier = PriorityQueue()
#frontier = SimpleQueue()
state = State(set(), set(range(NUM_SETS)))
frontier.put((distance(state), state))

counter = 0
_, current_state = frontier.get()
oldCost=0
while not goal_check(current_state):
    counter += 1
    for action in current_state[1]:
        new_state = State(
            current_state.taken ^ {action},
            current_state.not_taken ^ {action},
        )
        
        print("FUNC --> ", new_heuristic(new_state))
        #f = g(new_state) +  distance(new_state)  #F = G + H    --> where H is distance  
        f = g(new_state) + new_heuristic(new_state)
        
        print("\n\nCOSTO -->: " ,  f , " STATE: " ,  new_state)
        
        frontier.put((f, new_state))
    _, current_state = frontier.get()



#print_sets()
print(
    f"Solved in {counter:,} steps ({len(current_state.taken)} tiles. Sets used to cover {current_state.taken})"
)
#print_sets()
# Out:
# PRINTING SETS:
# 0) [False False False False  True]
# 1) [ True False False False  True]
# 2) [False False False False False]
# 3) [ True False False False False]
# 4) [False  True  True False False]
# 5) [ True False  True  True False]
# 6) [False False False  True False]
# -------------------------
# FUNC -->  3
#
#
# COSTO -->:  4  STATE:  State(taken={0}, not_taken={1, 2, 3, 4, 5, 6})
# FUNC -->  3
#
#
# COSTO -->:  4  STATE:  State(taken={1}, not_taken={0, 2, 3, 4, 5, 6})
# FUNC -->  3
#
#
# COSTO -->:  4  STATE:  State(taken={2}, not_taken={0, 1, 3, 4, 5, 6})
# FUNC -->  3
#
#
# COSTO -->:  4  STATE:  State(taken={3}, not_taken={0, 1, 2, 4, 5, 6})
# FUNC -->  3
#
#
# COSTO -->:  4  STATE:  State(taken={4}, not_taken={0, 1, 2, 3, 5, 6})
# FUNC -->  2
#
#
# COSTO -->:  3  STATE:  State(taken={5}, not_taken={0, 1, 2, 3, 4, 6})
# FUNC -->  3
#
#
# COSTO -->:  4  STATE:  State(taken={6}, not_taken={0, 1, 2, 3, 4, 5})
# FUNC -->  2
#
#
# COSTO -->:  4  STATE:  State(taken={0, 5}, not_taken={1, 2, 3, 4, 6})
# FUNC -->  2
#
#
# COSTO -->:  4  STATE:  State(taken={1, 5}, not_taken={0, 2, 3, 4, 6})
# FUNC -->  2
#
#
# COSTO -->:  4  STATE:  State(taken={2, 5}, not_taken={0, 1, 3, 4, 6})
# FUNC -->  2
#
#
# COSTO -->:  4  STATE:  State(taken={3, 5}, not_taken={0, 1, 2, 4, 6})
# FUNC -->  2
#
#
# COSTO -->:  4  STATE:  State(taken={4, 5}, not_taken={0, 1, 2, 3, 6})
# FUNC -->  2
#
#
# COSTO -->:  4  STATE:  State(taken={5, 6}, not_taken={0, 1, 2, 3, 4})
# FUNC -->  3
#
#
# COSTO -->:  5  STATE:  State(taken={0, 1}, not_taken={2, 3, 4, 5, 6})
# FUNC -->  3
#
#
# COSTO -->:  5  STATE:  State(taken={0, 2}, not_taken={1, 3, 4, 5, 6})
# FUNC -->  3
#
#
# COSTO -->:  5  STATE:  State(taken={0, 3}, not_taken={1, 2, 4, 5, 6})
# FUNC -->  3
#
#
# COSTO -->:  5  STATE:  State(taken={0, 4}, not_taken={1, 2, 3, 5, 6})
# FUNC -->  2
#
#
# COSTO -->:  4  STATE:  State(taken={0, 5}, not_taken={1, 2, 3, 4, 6})
# FUNC -->  3
#
#
# COSTO -->:  5  STATE:  State(taken={0, 6}, not_taken={1, 2, 3, 4, 5})
# FUNC -->  3
#
#
# COSTO -->:  5  STATE:  State(taken={0, 2}, not_taken={1, 3, 4, 5, 6})
# FUNC -->  3
#
#
# COSTO -->:  5  STATE:  State(taken={1, 2}, not_taken={0, 3, 4, 5, 6})
# FUNC -->  3
#
#
# COSTO -->:  5  STATE:  State(taken={2, 3}, not_taken={0, 1, 4, 5, 6})
# FUNC -->  3
#
#
# COSTO -->:  5  STATE:  State(taken={2, 4}, not_taken={0, 1, 3, 5, 6})
# FUNC -->  2
#
#
# COSTO -->:  4  STATE:  State(taken={2, 5}, not_taken={0, 1, 3, 4, 6})
# FUNC -->  3
#
#
# COSTO -->:  5  STATE:  State(taken={2, 6}, not_taken={0, 1, 3, 4, 5})
# FUNC -->  2
#
#
# COSTO -->:  5  STATE:  State(taken={0, 1, 5}, not_taken={2, 3, 4, 6})
# FUNC -->  2
#
#
# COSTO -->:  5  STATE:  State(taken={0, 2, 5}, not_taken={1, 3, 4, 6})
# FUNC -->  2
#
#
# COSTO -->:  5  STATE:  State(taken={0, 3, 5}, not_taken={1, 2, 4, 6})
# FUNC -->  2
#
#
# COSTO -->:  5  STATE:  State(taken={0, 4, 5}, not_taken={1, 2, 3, 6})
# FUNC -->  2
#
#
# COSTO -->:  5  STATE:  State(taken={0, 5, 6}, not_taken={1, 2, 3, 4})
# FUNC -->  3
#
#
# COSTO -->:  5  STATE:  State(taken={0, 6}, not_taken={1, 2, 3, 4, 5})
# FUNC -->  3
#
#
# COSTO -->:  5  STATE:  State(taken={1, 6}, not_taken={0, 2, 3, 4, 5})
# FUNC -->  3
#
#
# COSTO -->:  5  STATE:  State(taken={2, 6}, not_taken={0, 1, 3, 4, 5})
# FUNC -->  3
#
#
# COSTO -->:  5  STATE:  State(taken={3, 6}, not_taken={0, 1, 2, 4, 5})
# FUNC -->  3
#
#
# COSTO -->:  5  STATE:  State(taken={4, 6}, not_taken={0, 1, 2, 3, 5})
# FUNC -->  2
#
#
# COSTO -->:  4  STATE:  State(taken={5, 6}, not_taken={0, 1, 2, 3, 4})
# FUNC -->  2
#
#
# COSTO -->:  5  STATE:  State(taken={0, 5, 6}, not_taken={1, 2, 3, 4})
# FUNC -->  2
#
#
# COSTO -->:  5  STATE:  State(taken={1, 5, 6}, not_taken={0, 2, 3, 4})
# FUNC -->  2
#
#
# COSTO -->:  5  STATE:  State(taken={2, 5, 6}, not_taken={0, 1, 3, 4})
# FUNC -->  2
#
#
# COSTO -->:  5  STATE:  State(taken={3, 5, 6}, not_taken={0, 1, 2, 4})
# FUNC -->  2
#
#
# COSTO -->:  5  STATE:  State(taken={4, 5, 6}, not_taken={0, 1, 2, 3})
# FUNC -->  2
#
#
# COSTO -->:  5  STATE:  State(taken={0, 5, 6}, not_taken={1, 2, 3, 4})
# FUNC -->  2
#
#
# COSTO -->:  5  STATE:  State(taken={1, 5, 6}, not_taken={0, 2, 3, 4})
# FUNC -->  2
#
#
# COSTO -->:  5  STATE:  State(taken={2, 5, 6}, not_taken={0, 1, 3, 4})
# FUNC -->  2
#
#
# COSTO -->:  5  STATE:  State(taken={3, 5, 6}, not_taken={0, 1, 2, 4})
# FUNC -->  2
#
#
# COSTO -->:  5  STATE:  State(taken={4, 5, 6}, not_taken={0, 1, 2, 3})
# FUNC -->  3
#
#
# COSTO -->:  5  STATE:  State(taken={0, 1}, not_taken={2, 3, 4, 5, 6})
# FUNC -->  3
#
#
# COSTO -->:  5  STATE:  State(taken={1, 2}, not_taken={0, 3, 4, 5, 6})
# FUNC -->  3
#
#
# COSTO -->:  5  STATE:  State(taken={1, 3}, not_taken={0, 2, 4, 5, 6})
# FUNC -->  3
#
#
# COSTO -->:  5  STATE:  State(taken={1, 4}, not_taken={0, 2, 3, 5, 6})
# FUNC -->  2
#
#
# COSTO -->:  4  STATE:  State(taken={1, 5}, not_taken={0, 2, 3, 4, 6})
# FUNC -->  3
#
#
# COSTO -->:  5  STATE:  State(taken={1, 6}, not_taken={0, 2, 3, 4, 5})
# FUNC -->  3
#
#
# COSTO -->:  5  STATE:  State(taken={0, 4}, not_taken={1, 2, 3, 5, 6})
# FUNC -->  3
#
#
# COSTO -->:  5  STATE:  State(taken={1, 4}, not_taken={0, 2, 3, 5, 6})
# FUNC -->  3
#
#
# COSTO -->:  5  STATE:  State(taken={2, 4}, not_taken={0, 1, 3, 5, 6})
# FUNC -->  3
#
#
# COSTO -->:  5  STATE:  State(taken={3, 4}, not_taken={0, 1, 2, 5, 6})
# FUNC -->  2
#
#
# COSTO -->:  4  STATE:  State(taken={4, 5}, not_taken={0, 1, 2, 3, 6})
# FUNC -->  3
#
#
# COSTO -->:  5  STATE:  State(taken={4, 6}, not_taken={0, 1, 2, 3, 5})
# FUNC -->  2
#
#
# COSTO -->:  5  STATE:  State(taken={0, 4, 5}, not_taken={1, 2, 3, 6})
# FUNC -->  1
#
#
# COSTO -->:  4  STATE:  State(taken={1, 4, 5}, not_taken={0, 2, 3, 6})
# FUNC -->  2
#
#
# COSTO -->:  5  STATE:  State(taken={2, 4, 5}, not_taken={0, 1, 3, 6})
# FUNC -->  2
#
#
# COSTO -->:  5  STATE:  State(taken={3, 4, 5}, not_taken={0, 1, 2, 6})
# FUNC -->  2
#
#
# COSTO -->:  5  STATE:  State(taken={4, 5, 6}, not_taken={0, 1, 2, 3})
# FUNC -->  2
#
#
# COSTO -->:  5  STATE:  State(taken={0, 4, 5}, not_taken={1, 2, 3, 6})
# FUNC -->  1
#
#
# COSTO -->:  4  STATE:  State(taken={1, 4, 5}, not_taken={0, 2, 3, 6})
# FUNC -->  2
#
#
# COSTO -->:  5  STATE:  State(taken={2, 4, 5}, not_taken={0, 1, 3, 6})
# FUNC -->  2
#
#
# COSTO -->:  5  STATE:  State(taken={3, 4, 5}, not_taken={0, 1, 2, 6})
# FUNC -->  2
#
#
# COSTO -->:  5  STATE:  State(taken={4, 5, 6}, not_taken={0, 1, 2, 3})
# Solved in 12 steps (3 tiles. Sets used to cover {1, 4, 5})

# %%
# Solution using A* algorithm
def heuristic():
    pass

def cost():
    pass

def f(n):
    return cost(n) + heuristic(n)
