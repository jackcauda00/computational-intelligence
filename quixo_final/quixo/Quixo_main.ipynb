# %% [markdown]
# ## Work
# This project was designed, programmed and tested by
# * Lorenzo Bonannella
# * Giacomo Fantino
# * Farisan Fekri
# * Giacomo Cauda

# %%
import random
from game import Game, Move, Player
from copy import deepcopy
import sys
import numpy as np

class RandomPlayer(Player):
    def __init__(self) -> None:
        super().__init__()

    def make_move(self, game: 'Game') -> tuple[tuple[int, int], Move]:
        #game.print()
        from_pos = (random.randint(0, 4), random.randint(0, 4))
        move = random.choice([Move.TOP, Move.BOTTOM, Move.LEFT, Move.RIGHT])
        return from_pos, move

# %% [markdown]
# ## MinMax algorithm
#
# We started by using a MinMax strategy.
# Since the solution tree is huge we have to set a limit to the depth (cut-off). By doing some test we found that the evaluation of non terminal node could use the difference between zeroes and ones: in this way we are forcing our agent to choose to place more zeroes by picking neutral elements than picking zeroes tiles at the beginning of the games. The idea is that by putting more zeroes the chance of winning later is higher.

# %%
class MinMaxPlayer(Player):
    def __init__(self, max_depth=2) -> None:
        super().__init__()
        self.MAXIMUM_DEPTH = max_depth

    def make_move(self, game: 'Game') -> tuple[tuple[int, int], Move]:
        #game.print()
        _, combination = self.minmax(game, True, 0)
        return combination
    
    def minmax(self, game, maximizing_player, depth):
        # The MinMax algorithm function
        # It returns an evalution which a score for a certain player and the best move it can do
        if (game.check_winner() != -1 or depth==self.MAXIMUM_DEPTH):
            if game.check_winner() == 0:
                return 1, None
            elif game.check_winner() == 1:
                return -1, None
            else: # depth==self.MAXIMUM_DEPTH:
                #more zeroes the better since we are player 0
                num_zeros = np.count_nonzero(game._board == 0)
                num_ones = np.count_nonzero(game._board == 1)
                return (num_zeros - num_ones)/100, None
            #we take the solution with the highest number of 0

        depth = depth + 1 #increase depth        
        if maximizing_player:
            max_eval = float('-inf')
            best_move = None
            for possible_move in self.get_possible_moves(game, 0): #first player 
                new_game = self.get_new_board(game, possible_move, 0)
                eval, _ = self.minmax(new_game, False, depth)
                if eval > max_eval:
                    max_eval = eval
                    best_move = possible_move
            return max_eval, best_move
        else:
            min_eval = float('inf')
            best_move = None
            for possible_move in self.get_possible_moves(game, 1):  #second player 
                new_game = self.get_new_board(game, possible_move, 1)
                eval, _ = self.minmax(new_game, True, depth)
                if eval < min_eval:
                    min_eval = eval
                    best_move = possible_move
            return min_eval, best_move
    
    def get_new_board(self, game, possible_move, player):
        #We do a deepcopy of the game object because in MinMax we change the game not only the board attribute
        new_game = deepcopy(game)
        pos, move = possible_move
        res = new_game.move(pos, move, player) #we are trying the move 
        if not res:
            print(f'ERROR: SHOULDNT RECEIVE FALSE on {pos} and {move} player {player}')
            game.print()
            sys.exit(1)
        return new_game

    def acceptable_move(self, pos, mov):
         return not ((pos[1] == 0 and mov == Move.TOP) 
                     or (pos[1] == 4 and mov == Move.BOTTOM) 
                     or (pos[0] == 0 and mov == Move.LEFT)
                     or (pos[0] == 4 and mov == Move.RIGHT))

    def get_possible_moves(self, game, player):
        possible_pos = [(i, j) for i in range(0,5) for j in range(0, 5) 
                            if (i == 0 or i == 4 or j == 0 or j == 4) 
                            and (game._board[j,i] == -1 or game._board[j,i] == player)]
        
        possible_moves_pos = [(pos, mov) for pos in possible_pos for mov in [Move.TOP, Move.BOTTOM, Move.LEFT, Move.RIGHT]]
        #check if position and moves are feasable
        possible_moves_pos = [(pos, mov) for pos, mov in possible_moves_pos if self.acceptable_move(pos, mov)]
        return possible_moves_pos

# %% [markdown]
# To decide the limit of the depth we measured the time to evaluate the initial state (being that is the one with higher number of possible moves) for each possible depth. By looking at the results we decided to use depth equal to 2.

# %%
import time
initial_game = Game() #the empty board is the one it takes longer time

for depth in range(1, 4):
    player = MinMaxPlayer(max_depth=depth)
    start_time = time.time()

    _ = player.make_move(initial_game)

    end_time = time.time()

    print(f"Execution time for depth {depth}: {end_time - start_time} seconds")
# Out:
# Execution time for depth 1: 0.004042148590087891 seconds
# Execution time for depth 2: 0.16897869110107422 seconds
# Execution time for depth 3: 6.974924802780151 seconds

# %% [markdown]
# This is the function for testing our algorithm against a random player. We can see that our strategy was correct since we got almost 100% of winning rate.

# %%
wins = 0
player1 = MinMaxPlayer()
player2 = RandomPlayer()
for i in range(1000):
    print(f'starting game {i}')
    g = Game()
    winner = g.play(player1, player2)
    
    if winner == 0:
        wins += 1

print(f'I won {wins} time out of 1000')
# Out:
# starting game 0
# starting game 1
# starting game 2
# starting game 3
# starting game 4
# starting game 5
# starting game 6
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 7
#       5 print(f'starting game {i}')
#       6 g = Game()
# ----> 7 winner = g.play(player1, player2)
#       9 if winner == 0:
#      10     wins += 1
#
# File c:\Users\gcauda\Desktop\CI_venv\jack_git_comp_int\computational-intelligence\quixo_final\quixo\game.py:104, in Game.play(self, player1, player2)
#     102 ok = False
#     103 while not ok:
# --> 104     from_pos, slide = players[self.current_player_idx].make_move(
#     105         self)
#     106     ok = self.__move(from_pos, slide, self.current_player_idx)
#     107 winner = self.check_winner()
#
# Cell In[10], line 8, in MinMaxPlayer.make_move(self, game)
#       6 def make_move(self, game: 'Game') -> tuple[tuple[int, int], Move]:
#       7     #game.print()
# ----> 8     _, combination = self.minmax(game, True, 0)
#       9     return combination
#
# Cell In[10], line 32, in MinMaxPlayer.minmax(self, game, maximizing_player, depth)
#      30 for possible_move in self.get_possible_moves(game, 0): #first player
#      31     new_game = self.get_new_board(game, possible_move, 0)
# ---> 32     eval, _ = self.minmax(new_game, False, depth)
#      33     if eval > max_eval:
#      34         max_eval = eval
#
# Cell In[10], line 41, in MinMaxPlayer.minmax(self, game, maximizing_player, depth)
#      39 best_move = None
#      40 for possible_move in self.get_possible_moves(game, 1):  #second player
# ---> 41     new_game = self.get_new_board(game, possible_move, 1)
#      42     eval, _ = self.minmax(new_game, True, depth)
#      43     if eval < min_eval:
#
# Cell In[10], line 50, in MinMaxPlayer.get_new_board(self, game, possible_move, player)
#      48 def get_new_board(self, game, possible_move, player):
#      49     #We do a deepcopy of the game object because in MinMax we change the game not only the board attribute
# ---> 50     new_game = deepcopy(game)
#      51     pos, move = possible_move
#      52     res = new_game.move(pos, move, player) #we are trying the move
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\copy.py:162, in deepcopy(x, memo, _nil)
#     160                 y = x
#     161             else:
# --> 162                 y = _reconstruct(x, memo, *rv)
#     164 # If is its own copy, don't memoize.
#     165 if y is not x:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\copy.py:259, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     257 if state is not None:
#     258     if deep:
# --> 259         state = deepcopy(state, memo)
#     260     if hasattr(y, '__setstate__'):
#     261         y.__setstate__(state)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\copy.py:136, in deepcopy(x, memo, _nil)
#     134 copier = _deepcopy_dispatch.get(cls)
#     135 if copier is not None:
# --> 136     y = copier(x, memo)
#     137 else:
#     138     if issubclass(cls, type):
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\copy.py:221, in _deepcopy_dict(x, memo, deepcopy)
#     219 memo[id(x)] = y
#     220 for key, value in x.items():
# --> 221     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     222 return y
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\copy.py:143, in deepcopy(x, memo, _nil)
#     141 copier = getattr(x, "__deepcopy__", None)
#     142 if copier is not None:
# --> 143     y = copier(memo)
#     144 else:
#     145     reductor = dispatch_table.get(cls)
#
# KeyboardInterrupt:

# %% [markdown]
# ## MinMax algorithm with Alpha-Beta Pruning

# %% [markdown]
# Since the depth is very low due to the branching factor of the algorithm we decided to use alpha beta pruning to avoid to compute most of the subtrees.
# The strategy is the same as before (picking more zeroes than one) but now the _minmax function includes the alpha beta pruning.
# The basic idea is: in the case of the max player we receive from the parent node (min player) in the the current minimum value, in the variable beta. If we find a value which is higher than the minimum we can immediately stop because we won't change the decision of the parent node. The same happens when we are computing the min player.

# %%
class MinMaxPlayer(Player):
    def __init__(self, max_depth=3) -> None:
        super().__init__()
        self.MAXIMUM_DEPTH = max_depth

    def make_move(self, game: 'Game') -> tuple[tuple[int, int], Move]:
        #game.print()
        _, combination = self.minmax_alpha_beta(game, 0, -float('inf'), float('inf'), True)
        return combination

    def minmax_alpha_beta(self, game, depth, alpha, beta, maximizing_player):
        # The MinMax algorithm function with Alpha-Beta Pruning
        # alpha = current maximum value that we have found on that sub-branch
        # beta  = current minimum value that we have on that sub-branch
        # Base case: If the game is over or maximum depth is reached
        if (game.check_winner() != -1 or depth==self.MAXIMUM_DEPTH):
            if game.check_winner() == 0:
                return 1, None
            elif game.check_winner() == 1:
                return -1, None
            else: # depth==self.MAXIMUM_DEPTH 
                #more zeroes the better since we are player 0
                num_zeros = np.count_nonzero(game._board == 0)
                num_ones = np.count_nonzero(game._board == 1)
                return (num_zeros - num_ones)/100, None 
            #we take the solution with the highest number of 0
            
        depth = depth + 1 #increase depth 
        
        if maximizing_player:
            max_eval = float('-inf')
            best_move = None
            for possible_move in self.get_possible_moves(game, 0):
                new_game = self.get_new_board(game, possible_move, 0)
                eval, _ = self.minmax_alpha_beta(new_game, depth, alpha, beta, False)
                if eval > max_eval:
                    max_eval = eval
                    best_move = possible_move
                alpha = max(alpha, eval)
                if beta <= alpha:
                    break  # Beta cutoff    
            return max_eval, best_move
        else:
            min_eval = float('inf')
            best_move = None
            for possible_move in self.get_possible_moves(game, 1):  #second player
                new_game = self.get_new_board(game, possible_move, 1)
                eval, _ = self.minmax_alpha_beta(new_game, depth, alpha, beta, True)
                if eval < min_eval:
                    min_eval = eval
                    best_move = possible_move
                beta = min(beta, eval)
                if alpha > beta:
                    break  # Alpha cutoff
            return min_eval, best_move
    
    def get_new_board(self, game, possible_move, player):
        #We do a deepcopy of the game object because in MinMax we change the game not only the board attribute
        new_game = deepcopy(game)
        pos, move = possible_move
        res = new_game.move(pos, move, player) #we are trying the move 
        if not res:
            print(f'ERROR: SHOULDNT RECEIVE FALSE on {pos} and {move} player {player}')
            game.print()
            sys.exit(1)
        return new_game

    def acceptable_move(self, pos, mov):
         return not ((pos[1] == 0 and mov == Move.TOP) 
                     or (pos[1] == 4 and mov == Move.BOTTOM) 
                     or (pos[0] == 0 and mov == Move.LEFT) 
                     or (pos[0] == 4 and mov == Move.RIGHT))

    def get_possible_moves(self, game, player):
        possible_pos = [(i, j) for i in range(0,5) for j in range(0, 5) 
                            if (i == 0 or i == 4 or j == 0 or j == 4) 
                            and (game._board[j,i] == -1 or game._board[j,i] == player)]
        
        possible_moves_pos = [(pos, mov) for pos in possible_pos for mov in [Move.TOP, Move.BOTTOM, Move.LEFT, Move.RIGHT]]
        #check if position and moves are feasable
        possible_moves_pos = [(pos, mov) for pos, mov in possible_moves_pos if self.acceptable_move(pos, mov)]
        return possible_moves_pos

# %% [markdown]
# By reusing the same function as before we can see the huge improvement of using alpha beta pruning.

# %%
import time

initial_game = Game() #the empty board is the one it takes longer time

for depth in range(1, 6):
    player = MinMaxPlayer(max_depth=depth)
    start_time = time.time()

    _ = player.make_move(initial_game)

    end_time = time.time()

    print(f"Execution time for depth {depth}: {end_time - start_time} seconds")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 6
#       3 initial_game = Game() #the empty board is the one it takes longer time
#       5 for depth in range(1, 6):
# ----> 6     player = MinMaxPlayer(max_depth=depth)
#       7     start_time = time.time()
#       9     _ = player.make_move(initial_game)
#
# NameError: name 'MinMaxPlayer' is not defined

# %% [markdown]
# The results are the same as before but by printing the board after each move we concluded that the chosen moves done by minmax were more rational.

# %%
wins = 0
player1 = MinMaxPlayer()
player2 = RandomPlayer()
for i in range(1000):
    print(f'starting game {i}')
    g = Game()
    winner = g.play(player1, player2)
    
    if winner == 0:
        wins += 1

print(f'I won {wins} time out of 1000')
# Out:
# starting game 0
# starting game 1
# starting game 2
# starting game 3
# starting game 4
# ...
# ...
# ...
# I won 1000 time out of 1000

# %% [markdown]
# ## Reinforcement Learning with Monte Carlo approach

# %% [markdown]
# We decided to test a Reinforcement learning with this game: the agent will plays a certain number of games in a training phase to estimate a Q_function. We assume that by playing a lot of games the Q value of a node will converge to the expected reward of that node. Still we had some doubt since the tree is huge, so it may takes a lot of iterations to actually explore it.
#
# The Monte Carlo approach is the building base of this algorithm: we play a set of random games, see the results and use those to update all the nodes in the trajectories. We used a learning rate (the update weight) of 0.01.

# %%
from random import choice
from collections import defaultdict

class RL_Player(Player):
    def __init__(self) -> None:
        super().__init__()
        self.Q_func = defaultdict(float)

    '''
    Once we trained the agent, we use this function to play
    '''
    def make_move(self, game: 'Game') -> tuple[tuple[int, int], Move]:
        #game.print()
        moves = self.get_possible_moves(game, 0)
        #we assume we want the maximum reward possible
        reward = -float('inf')
        best_comb = None
        board_tuple = tuple(map(tuple, game._board))
        #let's get the best action for this scenario from the Q-function
        for mov in moves:
            rew = self.Q_func[(board_tuple, mov)]
            if rew > reward:
                reward = rew
                best_comb = mov
        
        from_pos, move = best_comb
        return from_pos, move
    
    def __random_game(self):
        state = Game()
        trajectory = []

        while True:
            #first player is US
            x = choice(self.get_possible_moves(state, 0))
            trajectory.append((deepcopy(state), x)) #current state + chosen action
            pos, move = x
            state.move(pos, move, 0)

            #check_winner != -1 because i can make a bad action
            if state.check_winner() != -1:
                break

            #opponent player (doesn't consider the state)
            y = choice(self.get_possible_moves(state, 1))
            pos, move = y
            state.move(pos, move, 1)

            if state.check_winner() != -1:
                break
            
        return trajectory, state #sequence of move for computing the state value function

    def state_value(self, state):
        return 1 if state.check_winner() == 0 else -1
    
    def train_agent(self, iterations, epsilon = 0.01):
        for _ in range(iterations):
            #print(f"ITERATION {i}")
            trajectory, last_state = self.__random_game()
            final_reward = self.state_value(last_state)
            for (state, action) in trajectory:
                #convert numpy to tuple to make it hashable
                board_tuple = tuple(map(tuple, state._board))
                hash_state = (board_tuple, action)
                difference = (final_reward - self.Q_func[hash_state])
                self.Q_func[hash_state] = self.Q_func[hash_state] + epsilon*difference
    

    def get_possible_moves(self, game, player):
        possible_pos = [(i, j) for i in range(0,5) for j in range(0, 5) 
                            if (i == 0 or i == 4 or j == 0 or j == 4) 
                            and (game._board[j,i] == -1 or game._board[j,i] == player)]
        
        possible_moves_pos = [(pos, mov) for pos in possible_pos for mov in [Move.TOP, Move.BOTTOM, Move.LEFT, Move.RIGHT]]
        #check if position and moves are feasable
        possible_moves_pos = [(pos, mov) for pos, mov in possible_moves_pos if self.acceptable_move(pos, mov)]
        return possible_moves_pos

    def acceptable_move(self, pos, mov):
         return not ((pos[1] == 0 and mov == Move.TOP) 
                     or (pos[1] == 4 and mov == Move.BOTTOM) 
                     or (pos[0] == 0 and mov == Move.LEFT)
                     or (pos[0] == 4 and mov == Move.RIGHT))

    def best_action_states(self, n):
        top = (sorted(self.Q_func.items(), key=lambda e : e[1], reverse = True)[:n])
        for key, value in top:
            print(f'key : {key}')
            print(f'value: {value}')
            print('')

# %% [markdown]
# Here the code to train and then test our agent:

# %%
player1 = RL_Player()
player2 = RandomPlayer()

training_its = 200_000
player1.train_agent(training_its)

win = 0
for _ in range(1000):
    g = Game()
    winner = g.play(player1, player2)
    if winner == 0:
        win += 1

print(f'We won {win} out of 1000 games')
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# Our doubts were correct: with 200_000 iterations the process took more than one hour and the results were not interesting. We tried changing the iterations and the learning rate:
#
# <img src="./loss.jpeg" alt="Plot of the loss functions" width=600/>

# %% [markdown]
# ## Reinforcement Learning with Monte Carlo approach and Parallization

# %% [markdown]
# For this last agent we added two strategies to the RL:
# * now it's possible to save the Q function and reload it later to be trained. This gave us the possibilites to train our agent for many iterations without our computers crashing.
# * Since the computation of a single game is independent from the others we used Thread Parallelization to speed up the execution.
#
# As we can see from the code we used two optimizations: ThreadPool and Future functions.
# 1) With threadpool we don't create a thread for each function call but only a fixed amount. Each thread will look at the queue and execute the function.
# 2) With Future we also parallelize the processing of the results: instead of waiting for all the threads to finish each time a thread stop we immediately process the result in a callback-fashion.

# %%
import concurrent.futures
import pickle

class RL_Player(Player):
    def __init__(self) -> None:
        super().__init__()
        self.Q_func = defaultdict(float)

    '''
    Once we trained the agent, we use this function to play
    '''
    def make_move(self, game: 'Game') -> tuple[tuple[int, int], Move]:
        #game.print()
        moves = self.get_possible_moves(game, 0)
        #we assume we want the maximum reward possible
        reward = -float('inf')
        best_comb = None
        board_tuple = tuple(map(tuple, game._board))
        #let's get the best action for this scenario from the Q-function
        for mov in moves:
            rew = self.Q_func[(board_tuple, mov)]
            if rew > reward:
                reward = rew
                best_comb = mov
        
        from_pos, move = best_comb
        return from_pos, move
    
    def _random_game(self):
        state = Game()
        trajectory = []

        while True:
            #first player is US
            x = choice(self.get_possible_moves(state, 0))
            trajectory.append((deepcopy(state), x)) #current state + chosen action
            pos, move = x
            state.move(pos, move, 0)

            #check_winner != -1 because i can make a bad action
            if state.check_winner() != -1:
                break

            #opponent player (doesn't consider the state)
            y = choice(self.get_possible_moves(state, 1))
            pos, move = y
            state.move(pos, move, 1)

            if state.check_winner() != -1:
                break
            
        return trajectory, state #sequence of move for computing the state value function

    def state_value(self, state):
        return 1 if state.check_winner() == 0 else -1
    
    def update_Q_func(self, hash_state, final_reward, epsilon):
        difference = (final_reward - self.Q_func[hash_state])
        self.Q_func[hash_state] = self.Q_func[hash_state] + epsilon * difference
    
    def train_agent(self, iterations, epsilon=0.01, save_dictionary=False):
        with concurrent.futures.ThreadPoolExecutor() as executor:
            futures = [executor.submit(self._random_game) for _ in range(iterations)]

            i = 1
            for future in concurrent.futures.as_completed(futures):
                i+=1
                print(f'process {i} finished')

                try:
                    trajectory, last_state = future.result()
                except Exception as e:
                    print(f'Error in process {i}: {e}')
                    continue  # Continue to the next iteration if there was an exception

                final_reward = self.state_value(last_state)

                for (state, action) in trajectory:
                    board_tuple = tuple(map(tuple, state._board))
                    hash_state = (board_tuple, action)
                    self.update_Q_func(hash_state, final_reward, epsilon)
    
        if save_dictionary:          
            # Specify the file path where you want to save the dictionary
            file_path = 'my_dictionary.pickle'

            pickle.dump(self.Q_func, open(file_path, 'wb')) #in case erase the old file
    
    def load_from_dictionary(self, file_path = 'my_dictionary.pickle'):
        # Load the dictionary from the file
        self.Q_func = pickle.load(open(file_path, 'rb'))
    
    def get_possible_moves(self, game, player):
        possible_pos = [(i, j) for i in range(0,5) for j in range(0, 5) 
                            if (i == 0 or i == 4 or j == 0 or j == 4) 
                            and (game._board[j,i] == -1 or game._board[j,i] == player)]
        
        possible_moves_pos = [(pos, mov) for pos in possible_pos for mov in [Move.TOP, Move.BOTTOM, Move.LEFT, Move.RIGHT]]
        #check if position and moves are feasable
        possible_moves_pos = [(pos, mov) for pos, mov in possible_moves_pos if self.acceptable_move(pos, mov)]
        return possible_moves_pos

    def acceptable_move(self, pos, mov):
         return not ((pos[1] == 0 and mov == Move.TOP) 
                     or (pos[1] == 4 and mov == Move.BOTTOM) 
                     or (pos[0] == 0 and mov == Move.LEFT)
                     or (pos[0] == 4 and mov == Move.RIGHT))

    def best_action_states(self, n):
        top = (sorted(self.Q_func.items(), key=lambda e : e[1], reverse = True)[:n])
        for key, value in top:
            print(f'key : {key}')
            print(f'value: {value}')
            print('')

# %% [markdown]
# We can start by seeing the improvements in the time:
#
# | Iterations | old RL       | improvements|
# |------------|--------------|-------------|
# | 50_000     | 3 min 40 sec | -30 sec     |
# | 200_000    | 1 hour 5 min | -20 min     |
#
# We can see a correlations between iterations and saved time.
#
# Performances wise we were able to reach more of a milion iterations by retraining the agent more times. Even by exploring a lot (the pickle file became 5GB) still the exploration was not enough and the results were only roughly 33% of winnings. This confirm the problem of exploring the entire quixo state space for the RL agent and confirm the minmax as the best agent.

# %%
#training phase
player1 = RL_Player()
player2 = RandomPlayer()

iterations = 1000
player1.load_from_dictionary()
player1.train_agent(iterations, save_dictionary=True)
#save_dictionary: if it's true it overrides the file with the dictionary with the new one
# Out:
# process 2 finished
# process 3 finished
# process 4 finished
# process 5 finished
# process 6 finished
# process 7 finished
# process 8 finished
# process 9 finished
# process 10 finished
# process 11 finished
# process 12 finished
# process 13 finished
# process 14 finished
# process 15 finished
# process 16 finished
# process 17 finished
# process 18 finished
# process 19 finished
# process 20 finished
# process 21 finished
# process 22 finished
# process 23 finished
# process 24 finished
# process 25 finished
# process 26 finished
# process 27 finished
# process 28 finished
# process 29 finished
# process 30 finished
# process 31 finished
# process 32 finished
# process 33 finished
# process 34 finished
# process 35 finished
# process 36 finished
# process 37 finished
# process 38 finished
# process 39 finished
# process 40 finished
# process 41 finished
# process 42 finished
# process 43 finished
# process 44 finished
# process 45 finished
# process 46 finished
# process 47 finished
# process 48 finished
# process 49 finished
# process 50 finished
# process 51 finished
# process 52 finished
# process 53 finished
# process 54 finished
# process 55 finished
# process 56 finished
# process 57 finished
# process 58 finished
# process 59 finished
# process 60 finished
# process 61 finished
# process 62 finished
# process 63 finished
# process 64 finished
# process 65 finished
# process 66 finished
# process 67 finished
# process 68 finished
# process 69 finished
# process 70 finished
# process 71 finished
# process 72 finished
# process 73 finished
# process 74 finished
# process 75 finished
# process 76 finished
# process 77 finished
# process 78 finished
# process 79 finished
# process 80 finished
# process 81 finished
# process 82 finished
# process 83 finished
# process 84 finished
# process 85 finished
# process 86 finished
# process 87 finished
# process 88 finished
# process 89 finished
# process 90 finished
# process 91 finished
# process 92 finished
# process 93 finished
# process 94 finished
# process 95 finished
# process 96 finished
# process 97 finished
# process 98 finished
# process 99 finished
# process 100 finished
# process 101 finished
# process 102 finished
# process 103 finished
# process 104 finished
# process 105 finished
# process 106 finished
# process 107 finished
# process 108 finished
# process 109 finished
# process 110 finished
# process 111 finished
# process 112 finished
# process 113 finished
# process 114 finished
# process 115 finished
# process 116 finished
# process 117 finished
# process 118 finished
# process 119 finished
# process 120 finished
# process 121 finished
# process 122 finished
# process 123 finished
# process 124 finished
# process 125 finished
# process 126 finished
# process 127 finished
# process 128 finished
# process 129 finished
# process 130 finished
# process 131 finished
# process 132 finished
# process 133 finished
# process 134 finished
# process 135 finished
# process 136 finished
# process 137 finished
# process 138 finished
# process 139 finished
# process 140 finished
# process 141 finished
# process 142 finished
# process 143 finished
# process 144 finished
# process 145 finished
# process 146 finished
# process 147 finished
# process 148 finished
# process 149 finished
# process 150 finished
# process 151 finished
# process 152 finished
# process 153 finished
# process 154 finished
# process 155 finished
# process 156 finished
# process 157 finished
# process 158 finished
# process 159 finished
# process 160 finished
# process 161 finished
# process 162 finished
# process 163 finished
# process 164 finished
# process 165 finished
# process 166 finished
# process 167 finished
# process 168 finished
# process 169 finished
# process 170 finished
# process 171 finished
# process 172 finished
# process 173 finished
# process 174 finished
# process 175 finished
# process 176 finished
# process 177 finished
# process 178 finished
# process 179 finished
# process 180 finished
# process 181 finished
# process 182 finished
# process 183 finished
# process 184 finished
# process 185 finished
# process 186 finished
# process 187 finished
# process 188 finished
# process 189 finished
# process 190 finished
# process 191 finished
# process 192 finished
# process 193 finished
# process 194 finished
# process 195 finished
# process 196 finished
# process 197 finished
# process 198 finished
# process 199 finished
# process 200 finished
# process 201 finished
# process 202 finished
# process 203 finished
# process 204 finished
# process 205 finished
# process 206 finished
# process 207 finished
# process 208 finished
# process 209 finished
# process 210 finished
# process 211 finished
# process 212 finished
# process 213 finished
# process 214 finished
# process 215 finished
# process 216 finished
# process 217 finished
# process 218 finished
# process 219 finished
# process 220 finished
# process 221 finished
# process 222 finished
# process 223 finished
# process 224 finished
# process 225 finished
# process 226 finished
# process 227 finished
# process 228 finished
# process 229 finished
# process 230 finished
# process 231 finished
# process 232 finished
# process 233 finished
# process 234 finished
# process 235 finished
# process 236 finished
# process 237 finished
# process 238 finished
# process 239 finished
# process 240 finished
# process 241 finished
# process 242 finished
# process 243 finished
# process 244 finished
# process 245 finished
# process 246 finished
# process 247 finished
# process 248 finished
# process 249 finished
# process 250 finished
# process 251 finished
# process 252 finished
# process 253 finished
# process 254 finished
# process 255 finished
# process 256 finished
# process 257 finished
# process 258 finished
# process 259 finished
# process 260 finished
# process 261 finished
# process 262 finished
# process 263 finished
# process 264 finished
# process 265 finished
# process 266 finished
# process 267 finished
# process 268 finished
# process 269 finished
# process 270 finished
# process 271 finished
# process 272 finished
# process 273 finished
# process 274 finished
# process 275 finished
# process 276 finished
# process 277 finished
# process 278 finished
# process 279 finished
# process 280 finished
# process 281 finished
# process 282 finished
# process 283 finished
# process 284 finished
# process 285 finished
# process 286 finished
# process 287 finished
# process 288 finished
# process 289 finished
# process 290 finished
# process 291 finished
# process 292 finished
# process 293 finished
# process 294 finished
# process 295 finished
# process 296 finished
# process 297 finished
# process 298 finished
# process 299 finished
# process 300 finished
# process 301 finished
# process 302 finished
# process 303 finished
# process 304 finished
# process 305 finished
# process 306 finished
# process 307 finished
# process 308 finished
# process 309 finished
# process 310 finished
# process 311 finished
# process 312 finished
# process 313 finished
# process 314 finished
# process 315 finished
# process 316 finished
# process 317 finished
# process 318 finished
# process 319 finished
# process 320 finished
# process 321 finished
# process 322 finished
# process 323 finished
# process 324 finished
# process 325 finished
# process 326 finished
# process 327 finished
# process 328 finished
# process 329 finished
# process 330 finished
# process 331 finished
# process 332 finished
# process 333 finished
# process 334 finished
# process 335 finished
# process 336 finished
# process 337 finished
# process 338 finished
# process 339 finished
# process 340 finished
# process 341 finished
# process 342 finished
# process 343 finished
# process 344 finished
# process 345 finished
# process 346 finished
# process 347 finished
# process 348 finished
# process 349 finished
# process 350 finished
# process 351 finished
# process 352 finished
# process 353 finished
# process 354 finished
# process 355 finished
# process 356 finished
# process 357 finished
# process 358 finished
# process 359 finished
# process 360 finished
# process 361 finished
# process 362 finished
# process 363 finished
# process 364 finished
# process 365 finished
# process 366 finished
# process 367 finished
# process 368 finished
# process 369 finished
# process 370 finished
# process 371 finished
# process 372 finished
# process 373 finished
# process 374 finished
# process 375 finished
# process 376 finished
# process 377 finished
# process 378 finished
# process 379 finished
# process 380 finished
# process 381 finished
# process 382 finished
# process 383 finished
# process 384 finished
# process 385 finished
# process 386 finished
# process 387 finished
# process 388 finished
# process 389 finished
# process 390 finished
# process 391 finished
# process 392 finished
# process 393 finished
# process 394 finished
# process 395 finished
# process 396 finished
# process 397 finished
# process 398 finished
# process 399 finished
# process 400 finished
# process 401 finished
# process 402 finished
# process 403 finished
# process 404 finished
# process 405 finished
# process 406 finished
# process 407 finished
# process 408 finished
# process 409 finished
# process 410 finished
# process 411 finished
# process 412 finished
# process 413 finished
# process 414 finished
# process 415 finished
# process 416 finished
# process 417 finished
# process 418 finished
# process 419 finished
# process 420 finished
# process 421 finished
# process 422 finished
# process 423 finished
# process 424 finished
# process 425 finished
# process 426 finished
# process 427 finished
# process 428 finished
# process 429 finished
# process 430 finished
# process 431 finished
# process 432 finished
# process 433 finished
# process 434 finished
# process 435 finished
# process 436 finished
# process 437 finished
# process 438 finished
# process 439 finished
# process 440 finished
# process 441 finished
# process 442 finished
# process 443 finished
# process 444 finished
# process 445 finished
# process 446 finished
# process 447 finished
# process 448 finished
# process 449 finished
# process 450 finished
# process 451 finished
# process 452 finished
# process 453 finished
# process 454 finished
# process 455 finished
# process 456 finished
# process 457 finished
# process 458 finished
# process 459 finished
# process 460 finished
# process 461 finished
# process 462 finished
# process 463 finished
# process 464 finished
# process 465 finished
# process 466 finished
# process 467 finished
# process 468 finished
# process 469 finished
# process 470 finished
# process 471 finished
# process 472 finished
# process 473 finished
# process 474 finished
# process 475 finished
# process 476 finished
# process 477 finished
# process 478 finished
# process 479 finished
# process 480 finished
# process 481 finished
# process 482 finished
# process 483 finished
# process 484 finished
# process 485 finished
# process 486 finished
# process 487 finished
# process 488 finished
# process 489 finished
# process 490 finished
# process 491 finished
# process 492 finished
# process 493 finished
# process 494 finished
# process 495 finished
# process 496 finished
# process 497 finished
# process 498 finished
# process 499 finished
# process 500 finished
# process 501 finished
# process 502 finished
# process 503 finished
# process 504 finished
# process 505 finished
# process 506 finished
# process 507 finished
# process 508 finished
# process 509 finished
# process 510 finished
# process 511 finished
# process 512 finished
# process 513 finished
# process 514 finished
# process 515 finished
# process 516 finished
# process 517 finished
# process 518 finished
# process 519 finished
# process 520 finished
# process 521 finished
# process 522 finished
# process 523 finished
# process 524 finished
# process 525 finished
# process 526 finished
# process 527 finished
# process 528 finished
# process 529 finished
# process 530 finished
# process 531 finished
# process 532 finished
# process 533 finished
# process 534 finished
# process 535 finished
# process 536 finished
# process 537 finished
# process 538 finished
# process 539 finished
# process 540 finished
# process 541 finished
# process 542 finished
# process 543 finished
# process 544 finished
# process 545 finished
# process 546 finished
# process 547 finished
# process 548 finished
# process 549 finished
# process 550 finished
# process 551 finished
# process 552 finished
# process 553 finished
# process 554 finished
# process 555 finished
# process 556 finished
# process 557 finished
# process 558 finished
# process 559 finished
# process 560 finished
# process 561 finished
# process 562 finished
# process 563 finished
# process 564 finished
# process 565 finished
# process 566 finished
# process 567 finished
# process 568 finished
# process 569 finished
# process 570 finished
# process 571 finished
# process 572 finished
# process 573 finished
# process 574 finished
# process 575 finished
# process 576 finished
# process 577 finished
# process 578 finished
# process 579 finished
# process 580 finished
# process 581 finished
# process 582 finished
# process 583 finished
# process 584 finished
# process 585 finished
# process 586 finished
# process 587 finished
# process 588 finished
# process 589 finished
# process 590 finished
# process 591 finished
# process 592 finished
# process 593 finished
# process 594 finished
# process 595 finished
# process 596 finished
# process 597 finished
# process 598 finished
# process 599 finished
# process 600 finished
# process 601 finished
# process 602 finished
# process 603 finished
# process 604 finished
# process 605 finished
# process 606 finished
# process 607 finished
# process 608 finished
# process 609 finished
# process 610 finished
# process 611 finished
# process 612 finished
# process 613 finished
# process 614 finished
# process 615 finished
# process 616 finished
# process 617 finished
# process 618 finished
# process 619 finished
# process 620 finished
# process 621 finished
# process 622 finished
# process 623 finished
# process 624 finished
# process 625 finished
# process 626 finished
# process 627 finished
# process 628 finished
# process 629 finished
# process 630 finished
# process 631 finished
# process 632 finished
# process 633 finished
# process 634 finished
# process 635 finished
# process 636 finished
# process 637 finished
# process 638 finished
# process 639 finished
# process 640 finished
# process 641 finished
# process 642 finished
# process 643 finished
# process 644 finished
# process 645 finished
# process 646 finished
# process 647 finished
# process 648 finished
# process 649 finished
# process 650 finished
# process 651 finished
# process 652 finished
# process 653 finished
# process 654 finished
# process 655 finished
# process 656 finished
# process 657 finished
# process 658 finished
# process 659 finished
# process 660 finished
# process 661 finished
# process 662 finished
# process 663 finished
# process 664 finished
# process 665 finished
# process 666 finished
# process 667 finished
# process 668 finished
# process 669 finished
# process 670 finished
# process 671 finished
# process 672 finished
# process 673 finished
# process 674 finished
# process 675 finished
# process 676 finished
# process 677 finished
# process 678 finished
# process 679 finished
# process 680 finished
# process 681 finished
# process 682 finished
# process 683 finished
# process 684 finished
# process 685 finished
# process 686 finished
# process 687 finished
# process 688 finished
# process 689 finished
# process 690 finished
# process 691 finished
# process 692 finished
# process 693 finished
# process 694 finished
# process 695 finished
# process 696 finished
# process 697 finished
# process 698 finished
# process 699 finished
# process 700 finished
# process 701 finished
# process 702 finished
# process 703 finished
# process 704 finished
# process 705 finished
# process 706 finished
# process 707 finished
# process 708 finished
# process 709 finished
# process 710 finished
# process 711 finished
# process 712 finished
# process 713 finished
# process 714 finished
# process 715 finished
# process 716 finished
# process 717 finished
# process 718 finished
# process 719 finished
# process 720 finished
# process 721 finished
# process 722 finished
# process 723 finished
# process 724 finished
# process 725 finished
# process 726 finished
# process 727 finished
# process 728 finished
# process 729 finished
# process 730 finished
# process 731 finished
# process 732 finished
# process 733 finished
# process 734 finished
# process 735 finished
# process 736 finished
# process 737 finished
# process 738 finished
# process 739 finished
# process 740 finished
# process 741 finished
# process 742 finished
# process 743 finished
# process 744 finished
# process 745 finished
# process 746 finished
# process 747 finished
# process 748 finished
# process 749 finished
# process 750 finished
# process 751 finished
# process 752 finished
# process 753 finished
# process 754 finished
# process 755 finished
# process 756 finished
# process 757 finished
# process 758 finished
# process 759 finished
# process 760 finished
# process 761 finished
# process 762 finished
# process 763 finished
# process 764 finished
# process 765 finished
# process 766 finished
# process 767 finished
# process 768 finished
# process 769 finished
# process 770 finished
# process 771 finished
# process 772 finished
# process 773 finished
# process 774 finished
# process 775 finished
# process 776 finished
# process 777 finished
# process 778 finished
# process 779 finished
# process 780 finished
# process 781 finished
# process 782 finished
# process 783 finished
# process 784 finished
# process 785 finished
# process 786 finished
# process 787 finished
# process 788 finished
# process 789 finished
# process 790 finished
# process 791 finished
# process 792 finished
# process 793 finished
# process 794 finished
# process 795 finished
# process 796 finished
# process 797 finished
# process 798 finished
# process 799 finished
# process 800 finished
# process 801 finished
# process 802 finished
# process 803 finished
# process 804 finished
# process 805 finished
# process 806 finished
# process 807 finished
# process 808 finished
# process 809 finished
# process 810 finished
# process 811 finished
# process 812 finished
# process 813 finished
# process 814 finished
# process 815 finished
# process 816 finished
# process 817 finished
# process 818 finished
# process 819 finished
# process 820 finished
# process 821 finished
# process 822 finished
# process 823 finished
# process 824 finished
# process 825 finished
# process 826 finished
# process 827 finished
# process 828 finished
# process 829 finished
# process 830 finished
# process 831 finished
# process 832 finished
# process 833 finished
# process 834 finished
# process 835 finished
# process 836 finished
# process 837 finished
# process 838 finished
# process 839 finished
# process 840 finished
# process 841 finished
# process 842 finished
# process 843 finished
# process 844 finished
# process 845 finished
# process 846 finished
# process 847 finished
# process 848 finished
# process 849 finished
# process 850 finished
# process 851 finished
# process 852 finished
# process 853 finished
# process 854 finished
# process 855 finished
# process 856 finished
# process 857 finished
# process 858 finished
# process 859 finished
# process 860 finished
# process 861 finished
# process 862 finished
# process 863 finished
# process 864 finished
# process 865 finished
# process 866 finished
# process 867 finished
# process 868 finished
# process 869 finished
# process 870 finished
# process 871 finished
# process 872 finished
# process 873 finished
# process 874 finished
# process 875 finished
# process 876 finished
# process 877 finished
# process 878 finished
# process 879 finished
# process 880 finished
# process 881 finished
# process 882 finished
# process 883 finished
# process 884 finished
# process 885 finished
# process 886 finished
# process 887 finished
# process 888 finished
# process 889 finished
# process 890 finished
# process 891 finished
# process 892 finished
# process 893 finished
# process 894 finished
# process 895 finished
# process 896 finished
# process 897 finished
# process 898 finished
# process 899 finished
# process 900 finished
# process 901 finished
# process 902 finished
# process 903 finished
# process 904 finished
# process 905 finished
# process 906 finished
# process 907 finished
# process 908 finished
# process 909 finished
# process 910 finished
# process 911 finished
# process 912 finished
# process 913 finished
# process 914 finished
# process 915 finished
# process 916 finished
# process 917 finished
# process 918 finished
# process 919 finished
# process 920 finished
# process 921 finished
# process 922 finished
# process 923 finished
# process 924 finished
# process 925 finished
# process 926 finished
# process 927 finished
# process 928 finished
# process 929 finished
# process 930 finished
# process 931 finished
# process 932 finished
# process 933 finished
# process 934 finished
# process 935 finished
# process 936 finished
# process 937 finished
# process 938 finished
# process 939 finished
# process 940 finished
# process 941 finished
# process 942 finished
# process 943 finished
# process 944 finished
# process 945 finished
# process 946 finished
# process 947 finished
# process 948 finished
# process 949 finished
# process 950 finished
# process 951 finished
# process 952 finished
# process 953 finished
# process 954 finished
# process 955 finished
# process 956 finished
# process 957 finished
# process 958 finished
# process 959 finished
# process 960 finished
# process 961 finished
# process 962 finished
# process 963 finished
# process 964 finished
# process 965 finished
# process 966 finished
# process 967 finished
# process 968 finished
# process 969 finished
# process 970 finished
# process 971 finished
# process 972 finished
# process 973 finished
# process 974 finished
# process 975 finished
# process 976 finished
# process 977 finished
# process 978 finished
# process 979 finished
# process 980 finished
# process 981 finished
# process 982 finished
# process 983 finished
# process 984 finished
# process 985 finished
# process 986 finished
# process 987 finished
# process 988 finished
# process 989 finished
# process 990 finished
# process 991 finished
# process 992 finished
# process 993 finished
# process 994 finished
# process 995 finished
# process 996 finished
# process 997 finished
# process 998 finished
# process 999 finished
# process 1000 finished
# process 1001 finished
# process 1002 finished
# process 1003 finished
# process 1004 finished
# process 1005 finished
# process 1006 finished
# process 1007 finished
# process 1008 finished
# process 1009 finished
# process 1010 finished
# process 1011 finished
# process 1012 finished
# process 1013 finished
# process 1014 finished
# process 1015 finished
# process 1016 finished
# process 1017 finished
# process 1018 finished
# process 1019 finished
# process 1020 finished
# process 1021 finished
# process 1022 finished
# process 1023 finished
# process 1024 finished
# process 1025 finished
# process 1026 finished
# process 1027 finished
# process 1028 finished
# process 1029 finished
# process 1030 finished
# process 1031 finished
# process 1032 finished
# process 1033 finished
# process 1034 finished
# process 1035 finished
# process 1036 finished
# process 1037 finished
# process 1038 finished
# process 1039 finished
# process 1040 finished
# process 1041 finished
# process 1042 finished
# process 1043 finished
# process 1044 finished
# process 1045 finished
# process 1046 finished
# process 1047 finished
# process 1048 finished
# process 1049 finished
# process 1050 finished
# process 1051 finished
# process 1052 finished
# process 1053 finished
# process 1054 finished
# process 1055 finished
# process 1056 finished
# process 1057 finished
# process 1058 finished
# process 1059 finished
# process 1060 finished
# process 1061 finished
# process 1062 finished
# process 1063 finished
# process 1064 finished
# process 1065 finished
# process 1066 finished
# process 1067 finished
# process 1068 finished
# process 1069 finished
# process 1070 finished
# process 1071 finished
# process 1072 finished
# process 1073 finished
# process 1074 finished
# process 1075 finished
# process 1076 finished
# process 1077 finished
# process 1078 finished
# process 1079 finished
# process 1080 finished
# process 1081 finished
# process 1082 finished
# process 1083 finished
# process 1084 finished
# process 1085 finished
# process 1086 finished
# process 1087 finished
# process 1088 finished
# process 1089 finished
# process 1090 finished
# process 1091 finished
# process 1092 finished
# process 1093 finished
# process 1094 finished
# process 1095 finished
# process 1096 finished
# process 1097 finished
# process 1098 finished
# process 1099 finished
# process 1100 finished
# process 1101 finished
# process 1102 finished
# process 1103 finished
# process 1104 finished
# process 1105 finished
# process 1106 finished
# process 1107 finished
# process 1108 finished
# process 1109 finished
# process 1110 finished
# process 1111 finished
# process 1112 finished
# process 1113 finished
# process 1114 finished
# process 1115 finished
# process 1116 finished
# process 1117 finished
# process 1118 finished
# process 1119 finished
# process 1120 finished
# process 1121 finished
# process 1122 finished
# process 1123 finished
# process 1124 finished
# process 1125 finished
# process 1126 finished
# process 1127 finished
# process 1128 finished
# process 1129 finished
# process 1130 finished
# process 1131 finished
# process 1132 finished
# process 1133 finished
# process 1134 finished
# process 1135 finished
# process 1136 finished
# process 1137 finished
# process 1138 finished
# process 1139 finished
# process 1140 finished
# process 1141 finished
# process 1142 finished
# process 1143 finished
# process 1144 finished
# process 1145 finished
# process 1146 finished
# process 1147 finished
# process 1148 finished
# process 1149 finished
# process 1150 finished
# process 1151 finished
# process 1152 finished
# process 1153 finished
# process 1154 finished
# process 1155 finished
# process 1156 finished
# process 1157 finished
# process 1158 finished
# process 1159 finished
# process 1160 finished
# process 1161 finished
# process 1162 finished
# process 1163 finished
# process 1164 finished
# process 1165 finished
# process 1166 finished
# process 1167 finished
# process 1168 finished
# process 1169 finished
# process 1170 finished
# process 1171 finished
# process 1172 finished
# process 1173 finished
# process 1174 finished
# process 1175 finished
# process 1176 finished
# process 1177 finished
# process 1178 finished
# process 1179 finished
# process 1180 finished
# process 1181 finished
# process 1182 finished
# process 1183 finished
# process 1184 finished
# process 1185 finished
# process 1186 finished
# process 1187 finished
# process 1188 finished
# process 1189 finished
# process 1190 finished
# process 1191 finished
# process 1192 finished
# process 1193 finished
# process 1194 finished
# process 1195 finished
# process 1196 finished
# process 1197 finished
# process 1198 finished
# process 1199 finished
# process 1200 finished
# process 1201 finished
# process 1202 finished
# process 1203 finished
# process 1204 finished
# process 1205 finished
# process 1206 finished
# process 1207 finished
# process 1208 finished
# process 1209 finished
# process 1210 finished
# process 1211 finished
# process 1212 finished
# process 1213 finished
# process 1214 finished
# process 1215 finished
# process 1216 finished
# process 1217 finished
# process 1218 finished
# process 1219 finished
# process 1220 finished
# process 1221 finished
# process 1222 finished
# process 1223 finished
# process 1224 finished
# process 1225 finished
# process 1226 finished
# process 1227 finished
# process 1228 finished
# process 1229 finished
# process 1230 finished
# process 1231 finished
# process 1232 finished
# process 1233 finished
# process 1234 finished
# process 1235 finished
# process 1236 finished
# process 1237 finished
# process 1238 finished
# process 1239 finished
# process 1240 finished
# process 1241 finished
# process 1242 finished
# process 1243 finished
# process 1244 finished
# process 1245 finished
# process 1246 finished
# process 1247 finished
# process 1248 finished
# process 1249 finished
# process 1250 finished
# process 1251 finished
# process 1252 finished
# process 1253 finished
# process 1254 finished
# process 1255 finished
# process 1256 finished
# process 1257 finished
# process 1258 finished
# process 1259 finished
# process 1260 finished
# process 1261 finished
# process 1262 finished
# process 1263 finished
# process 1264 finished
# process 1265 finished
# process 1266 finished
# process 1267 finished
# process 1268 finished
# process 1269 finished
# process 1270 finished
# process 1271 finished
# process 1272 finished
# process 1273 finished
# process 1274 finished
# process 1275 finished
# process 1276 finished
# process 1277 finished
# process 1278 finished
# process 1279 finished
# process 1280 finished
# process 1281 finished
# process 1282 finished
# process 1283 finished
# process 1284 finished
# process 1285 finished
# process 1286 finished
# process 1287 finished
# process 1288 finished
# process 1289 finished
# process 1290 finished
# process 1291 finished
# process 1292 finished
# process 1293 finished
# process 1294 finished
# process 1295 finished
# process 1296 finished
# process 1297 finished
# process 1298 finished
# process 1299 finished
# process 1300 finished
# process 1301 finished
# process 1302 finished
# process 1303 finished
# process 1304 finished
# process 1305 finished
# process 1306 finished
# process 1307 finished
# process 1308 finished
# process 1309 finished
# process 1310 finished
# process 1311 finished
# process 1312 finished
# process 1313 finished
# process 1314 finished
# process 1315 finished
# process 1316 finished
# process 1317 finished
# process 1318 finished
# process 1319 finished
# process 1320 finished
# process 1321 finished
# process 1322 finished
# process 1323 finished
# process 1324 finished
# process 1325 finished
# process 1326 finished
# process 1327 finished
# process 1328 finished
# process 1329 finished
# process 1330 finished
# process 1331 finished
# process 1332 finished
# process 1333 finished
# process 1334 finished
# process 1335 finished
# process 1336 finished
# process 1337 finished
# process 1338 finished
# process 1339 finished
# process 1340 finished
# process 1341 finished
# process 1342 finished
# process 1343 finished
# process 1344 finished
# process 1345 finished
# process 1346 finished
# process 1347 finished
# process 1348 finished
# process 1349 finished
# process 1350 finished
# process 1351 finished
# process 1352 finished
# process 1353 finished
# process 1354 finished
# process 1355 finished
# process 1356 finished
# process 1357 finished
# process 1358 finished
# process 1359 finished
# process 1360 finished
# process 1361 finished
# process 1362 finished
# process 1363 finished
# process 1364 finished
# process 1365 finished
# process 1366 finished
# process 1367 finished
# process 1368 finished
# process 1369 finished
# process 1370 finished
# process 1371 finished
# process 1372 finished
# process 1373 finished
# process 1374 finished
# process 1375 finished
# process 1376 finished
# process 1377 finished
# process 1378 finished
# process 1379 finished
# process 1380 finished
# process 1381 finished
# process 1382 finished
# process 1383 finished
# process 1384 finished
# process 1385 finished
# process 1386 finished
# process 1387 finished
# process 1388 finished
# process 1389 finished
# process 1390 finished
# process 1391 finished
# process 1392 finished
# process 1393 finished
# process 1394 finished
# process 1395 finished
# process 1396 finished
# process 1397 finished
# process 1398 finished
# process 1399 finished
# process 1400 finished
# process 1401 finished
# process 1402 finished
# process 1403 finished
# process 1404 finished
# process 1405 finished
# process 1406 finished
# process 1407 finished
# process 1408 finished
# process 1409 finished
# process 1410 finished
# process 1411 finished
# process 1412 finished
# process 1413 finished
# process 1414 finished
# process 1415 finished
# process 1416 finished
# process 1417 finished
# process 1418 finished
# process 1419 finished
# process 1420 finished
# process 1421 finished
# process 1422 finished
# process 1423 finished
# process 1424 finished
# process 1425 finished
# process 1426 finished
# process 1427 finished
# process 1428 finished
# process 1429 finished
# process 1430 finished
# process 1431 finished
# process 1432 finished
# process 1433 finished
# process 1434 finished
# process 1435 finished
# process 1436 finished
# process 1437 finished
# process 1438 finished
# process 1439 finished
# process 1440 finished
# process 1441 finished
# process 1442 finished
# process 1443 finished
# process 1444 finished
# process 1445 finished
# process 1446 finished
# process 1447 finished
# process 1448 finished
# process 1449 finished
# process 1450 finished
# process 1451 finished
# process 1452 finished
# process 1453 finished
# process 1454 finished
# process 1455 finished
# process 1456 finished
# process 1457 finished
# process 1458 finished
# process 1459 finished
# process 1460 finished
# process 1461 finished
# process 1462 finished
# process 1463 finished
# process 1464 finished
# process 1465 finished
# process 1466 finished
# process 1467 finished
# process 1468 finished
# process 1469 finished
# process 1470 finished
# process 1471 finished
# process 1472 finished
# process 1473 finished
# process 1474 finished
# process 1475 finished
# process 1476 finished
# process 1477 finished
# process 1478 finished
# process 1479 finished
# process 1480 finished
# process 1481 finished
# process 1482 finished
# process 1483 finished
# process 1484 finished
# process 1485 finished
# process 1486 finished
# process 1487 finished
# process 1488 finished
# process 1489 finished
# process 1490 finished
# process 1491 finished
# process 1492 finished
# process 1493 finished
# process 1494 finished
# process 1495 finished
# process 1496 finished
# process 1497 finished
# process 1498 finished
# process 1499 finished
# process 1500 finished
# process 1501 finished
# process 1502 finished
# process 1503 finished
# process 1504 finished
# process 1505 finished
# process 1506 finished
# process 1507 finished
# process 1508 finished
# process 1509 finished
# process 1510 finished
# process 1511 finished
# process 1512 finished
# process 1513 finished
# process 1514 finished
# process 1515 finished
# process 1516 finished
# process 1517 finished
# process 1518 finished
# process 1519 finished
# process 1520 finished
# process 1521 finished
# process 1522 finished
# process 1523 finished
# process 1524 finished
# process 1525 finished
# process 1526 finished
# process 1527 finished
# process 1528 finished
# process 1529 finished
# process 1530 finished
# process 1531 finished
# process 1532 finished
# process 1533 finished
# process 1534 finished
# process 1535 finished
# process 1536 finished
# process 1537 finished
# process 1538 finished
# process 1539 finished
# process 1540 finished
# process 1541 finished
# process 1542 finished
# process 1543 finished
# process 1544 finished
# process 1545 finished
# process 1546 finished
# process 1547 finished
# process 1548 finished
# process 1549 finished
# process 1550 finished
# process 1551 finished
# process 1552 finished
# process 1553 finished
# process 1554 finished
# process 1555 finished
# process 1556 finished
# process 1557 finished
# process 1558 finished
# process 1559 finished
# process 1560 finished
# process 1561 finished
# process 1562 finished
# process 1563 finished
# process 1564 finished
# process 1565 finished
# process 1566 finished
# process 1567 finished
# process 1568 finished
# process 1569 finished
# process 1570 finished
# process 1571 finished
# process 1572 finished
# process 1573 finished
# process 1574 finished
# process 1575 finished
# process 1576 finished
# process 1577 finished
# process 1578 finished
# process 1579 finished
# process 1580 finished
# process 1581 finished
# process 1582 finished
# process 1583 finished
# process 1584 finished
# process 1585 finished
# process 1586 finished
# process 1587 finished
# process 1588 finished
# process 1589 finished
# process 1590 finished
# process 1591 finished
# process 1592 finished
# process 1593 finished
# process 1594 finished
# process 1595 finished
# process 1596 finished
# process 1597 finished
# process 1598 finished
# process 1599 finished
# process 1600 finished
# process 1601 finished
# process 1602 finished
# process 1603 finished
# process 1604 finished
# process 1605 finished
# process 1606 finished
# process 1607 finished
# process 1608 finished
# process 1609 finished
# process 1610 finished
# process 1611 finished
# process 1612 finished
# process 1613 finished
# process 1614 finished
# process 1615 finished
# process 1616 finished
# process 1617 finished
# process 1618 finished
# process 1619 finished
# process 1620 finished
# process 1621 finished
# process 1622 finished
# process 1623 finished
# process 1624 finished
# process 1625 finished
# process 1626 finished
# process 1627 finished
# process 1628 finished
# process 1629 finished
# process 1630 finished
# process 1631 finished
# process 1632 finished
# process 1633 finished
# process 1634 finished
# process 1635 finished
# process 1636 finished
# process 1637 finished
# process 1638 finished
# process 1639 finished
# process 1640 finished
# process 1641 finished
# process 1642 finished
# process 1643 finished
# process 1644 finished
# process 1645 finished
# process 1646 finished
# process 1647 finished
# process 1648 finished
# process 1649 finished
# process 1650 finished
# process 1651 finished
# process 1652 finished
# process 1653 finished
# process 1654 finished
# process 1655 finished
# process 1656 finished
# process 1657 finished
# process 1658 finished
# process 1659 finished
# process 1660 finished
# process 1661 finished
# process 1662 finished
# process 1663 finished
# process 1664 finished
# process 1665 finished
# process 1666 finished
# process 1667 finished
# process 1668 finished
# process 1669 finished
# process 1670 finished
# process 1671 finished
# process 1672 finished
# process 1673 finished
# process 1674 finished
# process 1675 finished
# process 1676 finished
# process 1677 finished
# process 1678 finished
# process 1679 finished
# process 1680 finished
# process 1681 finished
# process 1682 finished
# process 1683 finished
# process 1684 finished
# process 1685 finished
# process 1686 finished
# process 1687 finished
# process 1688 finished
# process 1689 finished
# process 1690 finished
# process 1691 finished
# process 1692 finished
# process 1693 finished
# process 1694 finished
# process 1695 finished
# process 1696 finished
# process 1697 finished
# process 1698 finished
# process 1699 finished
# process 1700 finished
# process 1701 finished
# process 1702 finished
# process 1703 finished
# process 1704 finished
# process 1705 finished
# process 1706 finished
# process 1707 finished
# process 1708 finished
# process 1709 finished
# process 1710 finished
# process 1711 finished
# process 1712 finished
# process 1713 finished
# process 1714 finished
# process 1715 finished
# process 1716 finished
# process 1717 finished
# process 1718 finished
# process 1719 finished
# process 1720 finished
# process 1721 finished
# process 1722 finished
# process 1723 finished
# process 1724 finished
# process 1725 finished
# process 1726 finished
# process 1727 finished
# process 1728 finished
# process 1729 finished
# process 1730 finished
# process 1731 finished
# process 1732 finished
# process 1733 finished
# process 1734 finished
# process 1735 finished
# process 1736 finished
# process 1737 finished
# process 1738 finished
# process 1739 finished
# process 1740 finished
# process 1741 finished
# process 1742 finished
# process 1743 finished
# process 1744 finished
# process 1745 finished
# process 1746 finished
# process 1747 finished
# process 1748 finished
# process 1749 finished
# process 1750 finished
# process 1751 finished
# process 1752 finished
# process 1753 finished
# process 1754 finished
# process 1755 finished
# process 1756 finished
# process 1757 finished
# process 1758 finished
# process 1759 finished
# process 1760 finished
# process 1761 finished
# process 1762 finished
# process 1763 finished
# process 1764 finished
# process 1765 finished
# process 1766 finished
# process 1767 finished
# process 1768 finished
# process 1769 finished
# process 1770 finished
# process 1771 finished
# process 1772 finished
# process 1773 finished
# process 1774 finished
# process 1775 finished
# process 1776 finished
# process 1777 finished
# process 1778 finished
# process 1779 finished
# process 1780 finished
# process 1781 finished
# process 1782 finished
# process 1783 finished
# process 1784 finished
# process 1785 finished
# process 1786 finished
# process 1787 finished
# process 1788 finished
# process 1789 finished
# process 1790 finished
# process 1791 finished
# process 1792 finished
# process 1793 finished
# process 1794 finished
# process 1795 finished
# process 1796 finished
# process 1797 finished
# process 1798 finished
# process 1799 finished
# process 1800 finished
# process 1801 finished
# process 1802 finished
# process 1803 finished
# process 1804 finished
# process 1805 finished
# process 1806 finished
# process 1807 finished
# process 1808 finished
# process 1809 finished
# process 1810 finished
# process 1811 finished
# process 1812 finished
# process 1813 finished
# process 1814 finished
# process 1815 finished
# process 1816 finished
# process 1817 finished
# process 1818 finished
# process 1819 finished
# process 1820 finished
# process 1821 finished
# process 1822 finished
# process 1823 finished
# process 1824 finished
# process 1825 finished
# process 1826 finished
# process 1827 finished
# process 1828 finished
# process 1829 finished
# process 1830 finished
# process 1831 finished
# process 1832 finished
# process 1833 finished
# process 1834 finished
# process 1835 finished
# process 1836 finished
# process 1837 finished
# process 1838 finished
# process 1839 finished
# process 1840 finished
# process 1841 finished
# process 1842 finished
# process 1843 finished
# process 1844 finished
# process 1845 finished
# process 1846 finished
# process 1847 finished
# process 1848 finished
# process 1849 finished
# process 1850 finished
# process 1851 finished
# process 1852 finished
# process 1853 finished
# process 1854 finished
# process 1855 finished
# process 1856 finished
# process 1857 finished
# process 1858 finished
# process 1859 finished
# process 1860 finished
# process 1861 finished
# process 1862 finished
# process 1863 finished
# process 1864 finished
# process 1865 finished
# process 1866 finished
# process 1867 finished
# process 1868 finished
# process 1869 finished
# process 1870 finished
# process 1871 finished
# process 1872 finished
# process 1873 finished
# process 1874 finished
# process 1875 finished
# process 1876 finished
# process 1877 finished
# process 1878 finished
# process 1879 finished
# process 1880 finished
# process 1881 finished
# process 1882 finished
# process 1883 finished
# process 1884 finished
# process 1885 finished
# process 1886 finished
# process 1887 finished
# process 1888 finished
# process 1889 finished
# process 1890 finished
# process 1891 finished
# process 1892 finished
# process 1893 finished
# process 1894 finished
# process 1895 finished
# process 1896 finished
# process 1897 finished
# process 1898 finished
# process 1899 finished
# process 1900 finished
# process 1901 finished
# process 1902 finished
# process 1903 finished
# process 1904 finished
# process 1905 finished
# process 1906 finished
# process 1907 finished
# process 1908 finished
# process 1909 finished
# process 1910 finished
# process 1911 finished
# process 1912 finished
# process 1913 finished
# process 1914 finished
# process 1915 finished
# process 1916 finished
# process 1917 finished
# process 1918 finished
# process 1919 finished
# process 1920 finished
# process 1921 finished
# process 1922 finished
# process 1923 finished
# process 1924 finished
# process 1925 finished
# process 1926 finished
# process 1927 finished
# process 1928 finished
# process 1929 finished
# process 1930 finished
# process 1931 finished
# process 1932 finished
# process 1933 finished
# process 1934 finished
# process 1935 finished
# process 1936 finished
# process 1937 finished
# process 1938 finished
# process 1939 finished
# process 1940 finished
# process 1941 finished
# process 1942 finished
# process 1943 finished
# process 1944 finished
# process 1945 finished
# process 1946 finished
# process 1947 finished
# process 1948 finished
# process 1949 finished
# process 1950 finished
# process 1951 finished
# process 1952 finished
# process 1953 finished
# process 1954 finished
# process 1955 finished
# process 1956 finished
# process 1957 finished
# process 1958 finished
# process 1959 finished
# process 1960 finished
# process 1961 finished
# process 1962 finished
# process 1963 finished
# process 1964 finished
# process 1965 finished
# process 1966 finished
# process 1967 finished
# process 1968 finished
# process 1969 finished
# process 1970 finished
# process 1971 finished
# process 1972 finished
# process 1973 finished
# process 1974 finished
# process 1975 finished
# process 1976 finished
# process 1977 finished
# process 1978 finished
# process 1979 finished
# process 1980 finished
# process 1981 finished
# process 1982 finished
# process 1983 finished
# process 1984 finished
# process 1985 finished
# process 1986 finished
# process 1987 finished
# process 1988 finished
# process 1989 finished
# process 1990 finished
# process 1991 finished
# process 1992 finished
# process 1993 finished
# process 1994 finished
# process 1995 finished
# process 1996 finished
# process 1997 finished
# process 1998 finished
# process 1999 finished
# process 2000 finished
# process 2001 finished

# %%
#test phase
player1 = RL_Player()
player2 = RandomPlayer()

player1.load_from_dictionary()

win = 0
for _ in range(1000):
    g = Game()
    winner = g.play(player1, player2)
    if winner == 0:
        win += 1

print(f'We won {win} out of 1000 games')
